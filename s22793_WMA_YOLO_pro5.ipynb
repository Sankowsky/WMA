# %% [markdown]
# <a href="https://colab.research.google.com/github/Sankowsky/WMA/blob/main/s22793_WMA_YOLO_pro5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://docs.ultralytics.com/yolov5/tutorials/train_custom_data/

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 15705 (delta 9), reused 14 (delta 3), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.51 MiB | 12.59 MiB/s, done.
# Resolving deltas: 100% (10754/10754), done.

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 56.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 24.2 MB/s eta 0:00:00
# ...

# %%
# !ls -l yolov5
# Out:
# total 328
# -rw-r--r-- 1 root root  7831 May 28 13:12 benchmarks.py
# -rw-r--r-- 1 root root   393 May 28 13:12 CITATION.cff
# drwxr-xr-x 2 root root  4096 May 28 13:12 classify
# -rw-r--r-- 1 root root  5009 May 28 13:12 CONTRIBUTING.md
# drwxr-xr-x 5 root root  4096 May 28 13:12 data
# -rw-r--r-- 1 root root 14320 May 28 13:12 detect.py
# -rw-r--r-- 1 root root 39115 May 28 13:12 export.py
# -rw-r--r-- 1 root root  7769 May 28 13:12 hubconf.py
# -rw-r--r-- 1 root root 34523 May 28 13:12 LICENSE
# drwxr-xr-x 4 root root  4096 May 28 13:12 models
# -rw-r--r-- 1 root root 41308 May 28 13:12 README.md
# -rw-r--r-- 1 root root 40334 May 28 13:12 README.zh-CN.md
# -rw-r--r-- 1 root root  1554 May 28 13:12 requirements.txt
# drwxr-xr-x 2 root root  4096 May 28 13:12 segment
# -rw-r--r-- 1 root root  1727 May 28 13:12 setup.cfg
# -rw-r--r-- 1 root root 33767 May 28 13:12 train.py
# -rw-r--r-- 1 root root 40908 May 28 13:12 tutorial.ipynb
# drwxr-xr-x 8 root root  4096 May 28 13:12 utils
# ...

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !ls -l yolov5
# Out:
# total 336
# -rw-r--r-- 1 root root  7831 May 22 12:36 benchmarks.py
# -rw-r--r-- 1 root root   393 May 22 12:36 CITATION.cff
# drwxr-xr-x 2 root root  4096 May 22 12:36 classify
# -rw-r--r-- 1 root root  5009 May 22 12:36 CONTRIBUTING.md
# drwxr-xr-x 5 root root  4096 May 22 12:36 data
# -rw-r--r-- 1 root root 14320 May 22 12:36 detect.py
# -rw-r--r-- 1 root root 39115 May 22 12:36 export.py
# -rw-r--r-- 1 root root  7769 May 22 12:36 hubconf.py
# -rw-r--r-- 1 root root 34523 May 22 12:36 LICENSE
# drwxr-xr-x 5 root root  4096 May 22 12:36 models
# drwxr-xr-x 2 root root  4096 May 22 12:36 __pycache__
# -rw-r--r-- 1 root root 41306 May 22 12:36 README.md
# -rw-r--r-- 1 root root 40332 May 22 12:36 README.zh-CN.md
# -rw-r--r-- 1 root root  1554 May 22 12:36 requirements.txt
# drwxr-xr-x 3 root root  4096 May 22 12:36 runs
# drwxr-xr-x 2 root root  4096 May 22 12:36 segment
# -rw-r--r-- 1 root root  1727 May 22 12:36 setup.cfg
# -rw-r--r-- 1 root root 33767 May 22 12:36 train.py
# ...

# %%
# !python yolov5/detect.py --source VID_20220907_193558.mp4
# Out:
# detect: weights=yolov5/yolov5s.pt, source=VID_20220907_193558.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-171-g6e04b94 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 70.3MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x63e5f640] Detected moov in a free or hoov atom.
# video 1/1 (1/364) /content/VID_20220907_193558.mp4: 640x384 3 persons, 1 bicycle, 2 cars, 56.6ms
# video 1/1 (2/364) /content/VID_20220907_193558.mp4: 640x384 8 persons, 2 cars, 12.0ms
# ...

# %% [markdown]
# # zad 1
# Przygotuj zbiór danych z minimum 4 kategoriami. Z każdej kategori ma być minimum 10 przykładów i w sumie ma być minimum 20 zdjęć. Z zaznaczeniem że jeśli zdjęcia są z jednego filmu lub jednej sytuacji, czyli mają podobne oświetlenie, to przykłądów powinno być minimum 2 razy więcej.

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qQCfXOzW1DrHxQmSOgFo")
project = rf.workspace("pjatk-ql5xf").project("miw_pro5_detection")
dataset = project.version(1).download("yolov5")
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.0 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=aec8b491d69ccf5bb5f18889ac61aa56b8087e53d5b75e434510e0551a625f3a
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
# ...

# %% [markdown]
# # zad 2
# Wybierz odpowiedni dla siebie model i wytrenuj na losowych wagach oraz na juz wytrenowanych.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# !cd yolov5
#!ls
# !pip install -r yolov5/requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 15705 (delta 9), reused 15 (delta 3), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.51 MiB | 18.52 MiB/s, done.
# Resolving deltas: 100% (10754/10754), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 592.7/592.7 kB 33.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# ...

# %%
# !python yolov5/train.py --img 640 --epochs 3 --data yolov5/MIW_PRO5_Detection-1/data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=yolov5/MIW_PRO5_Detection-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# ...

# %%
# !python yolov5/train.py --img 640 --epochs 3 --data yolov5/MIW_PRO5_Detection-1/data.yaml --weights '' --cfg yolov5s.yaml

# %%
# !python yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --source /content/yolov5/MIW_PRO5_Detection-1/train/images/Virgin-Wines_Image-01_png.rf.fbd96cac5d87bb5b603b21274d781c69.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/yolov5/MIW_PRO5_Detection-1/train/images/Virgin-Wines_Image-01_png.rf.fbd96cac5d87bb5b603b21274d781c69.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/MIW_PRO5_Detection-1/train/images/Virgin-Wines_Image-01_png.rf.fbd96cac5d87bb5b603b21274d781c69.jpg: 640x640 (no detections), 417.3ms
# ...

# %%
# !python yolov5/detect.py --source /content/yolov5/MIW_PRO5_Detection-1/train/images/Virgin-Wines_Image-01_png.rf.fbd96cac5d87bb5b603b21274d781c69.jpg
# Out:
# detect: weights=yolov5/yolov5s.pt, source=/content/yolov5/MIW_PRO5_Detection-1/train/images/Virgin-Wines_Image-01_png.rf.fbd96cac5d87bb5b603b21274d781c69.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/1 /content/yolov5/MIW_PRO5_Detection-1/train/images/Virgin-Wines_Image-01_png.rf.fbd96cac5d87bb5b603b21274d781c69.jpg: 640x640 3 bottles, 1 wine glass, 1 cup, 1 sandwich, 12.2ms
# ...

# %%
# !python yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --source /content/drive/MyDrive/IMG_6364.MOV
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/IMG_6364.MOV, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/322) /content/drive/MyDrive/IMG_6364.MOV: 384x640 (no detections), 257.3ms
# video 1/1 (2/322) /content/drive/MyDrive/IMG_6364.MOV: 384x640 (no detections), 279.5ms
# video 1/1 (3/322) /content/drive/MyDrive/IMG_6364.MOV: 384x640 (no detections), 230.8ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # zad 3
# Wykonaj detekcję obydwu modeli na przykładowym filmie i porównaj rezultaty.
